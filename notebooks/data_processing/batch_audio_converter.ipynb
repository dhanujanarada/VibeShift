# %% [markdown]
# # Batch Audio-to-MIDI-to-Audio Converter
#
# This notebook performs batch conversion of audio files to MIDI and back to audio using basic_pitch for transcription and FluidSynth for synthesis. It includes progress tracking and audio visualization.
#
# **Process:**
# 1. Audio → MIDI (using basic_pitch)
# 2. MIDI → Audio (using FluidSynth)
# 3. Visualization and comparison of original vs. resynthesized audio

# %% [markdown]
# ## 1. Import Required Libraries and Setup

# %%
import sys
import os
from pathlib import Path
from typing import Dict, List
import time
from datetime import datetime

# Add parent directory to path for imports
sys.path.insert(0, str(Path.cwd().parent / "utills"))

import librosa
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Audio, display
import soundfile as sf

# Import our converter class
from utills.audio_midi_converter import AudioMidiConverter

print("✓ All libraries imported successfully!")
print(f"Current working directory: {Path.cwd()}")
# Out:
# WARNING:root:Coremltools is not installed. If you plan to use a CoreML Saved Model, reinstall basic-pitch with `pip install 'basic-pitch[coreml]'`
# WARNING:root:tflite-runtime is not installed. If you plan to use a TFLite Model, reinstall basic-pitch with `pip install 'basic-pitch tflite-runtime'` or `pip install 'basic-pitch[tf]'
# WARNING:root:Tensorflow is not installed. If you plan to use a TF Saved Model, reinstall basic-pitch with `pip install 'basic-pitch[tf]'`
# c:\Users\Dhanuja\Desktop\Vibeshift\VibeShift\.venv\lib\site-packages\resampy\filters.py:50: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# ✓ All libraries imported successfully!
# Current working directory: c:\Users\Dhanuja\Desktop\Vibeshift\VibeShift\notebooks\data_processing

# %% [markdown]
# ## 2. Initialize the Converter

# %%
print("Initializing AudioMidiConverter...")
print("=" * 60)

try:
    converter = AudioMidiConverter()
    print("✓ Converter initialized successfully!")
    print(f"  Soundfont: {converter.soundfont_path}")
    print(f"  FluidSynth: {converter.fluidsynth_path}")
    print("=" * 60)
except Exception as e:
    print(f"✗ Error initializing converter: {e}")
    raise
# Out:
# Initializing AudioMidiConverter...
# ============================================================
# ✓ Converter initialized successfully!
#   Soundfont: C:\Users\Dhanuja\Desktop\Vibeshift\VibeShift\data\TimGM6mb.sf2
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
# ============================================================

# %% [markdown]
# ## 3. Define Batch Processing Function

# %%
def batch_convert_audio_files(input_dir: str, output_dir: str, 
                               audio_formats: List[str] = None) -> Dict[str, str]:
    """
    Batch convert audio files to MIDI and back to audio.
    
    Args:
        input_dir: Directory containing audio files
        output_dir: Directory to save converted files
        audio_formats: List of audio extensions to process
        
    Returns:
        Dictionary mapping input files to output files
    """
    if audio_formats is None:
        audio_formats = ['.wav', '.mp3', '.flac']
    
    # Validate input directory
    if not os.path.exists(input_dir):
        raise FileNotFoundError(f"Input directory not found: {input_dir}")
    
    # Create output directory
    os.makedirs(output_dir, exist_ok=True)
    
    # Find all audio files
    audio_files = []
    for ext in audio_formats:
        audio_files.extend(Path(input_dir).glob(f"*{ext}"))
        audio_files.extend(Path(input_dir).glob(f"*{ext.upper()}"))
    
    # Remove duplicates
    audio_files = list(set(audio_files))
    
    if not audio_files:
        print(f"✗ No audio files found in {input_dir}")
        return {}
    
    results = {}
    start_time = time.time()
    
    print(f"\n{'='*70}")
    print(f"🎵 BATCH CONVERSION STARTED")
    print(f"{'='*70}")
    print(f"Input Directory:  {os.path.abspath(input_dir)}")
    print(f"Output Directory: {os.path.abspath(output_dir)}")
    print(f"Files to Process: {len(audio_files)}")
    print(f"Start Time:       {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print(f"{'='*70}\n")
    
    # Process each audio file
    for idx, audio_file in enumerate(audio_files, 1):
        file_start = time.time()
        file_name = audio_file.name
        
        print(f"[{idx}/{len(audio_files)}] Processing: {file_name}")
        print(f"  └─ Started at {datetime.now().strftime('%H:%M:%S')}")
        
        try:
            # Convert audio to MIDI to audio
            output_audio = converter.convert(str(audio_file), output_dir)
            results[str(audio_file)] = output_audio
            
            file_duration = time.time() - file_start
            output_size = os.path.getsize(output_audio) / (1024 * 1024)  # MB
            
            print(f"  └─ ✓ Success ({file_duration:.1f}s, {output_size:.2f} MB)")
            print(f"  └─ Output: {Path(output_audio).name}\n")
            
        except Exception as e:
            print(f"  └─ ✗ Error: {str(e)}\n")
            results[str(audio_file)] = None
    
    total_duration = time.time() - start_time
    successful = sum(1 for v in results.values() if v is not None)
    
    print(f"{'='*70}")
    print(f"🎵 BATCH CONVERSION COMPLETED")
    print(f"{'='*70}")
    print(f"Total Time:       {total_duration:.1f}s ({total_duration/60:.1f} minutes)")
    print(f"Successful:       {successful}/{len(audio_files)}")
    print(f"Success Rate:     {(successful/len(audio_files)*100):.1f}%")
    print(f"End Time:         {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print(f"{'='*70}\n")
    
    return results

print("✓ Batch processing function defined")
# Out:
# ✓ Batch processing function defined

# %% [markdown]
# ## 4. Process Multiple Audio Files
#
# Specify the input directory containing audio files and the output directory for converted files.

# %%
# Configuration: Specify your input and output directories
INPUT_DIR = r"C:\Users\Dhanuja\Downloads\dataset\punk_data"  # Change this to your input directory
OUTPUT_DIR = r"C:\Users\Dhanuja\Downloads\dataset\source"       # Change this to your desired output directory

# Run batch conversion
conversion_results = batch_convert_audio_files(INPUT_DIR, OUTPUT_DIR)
# Out:
# ======================================================================
# 🎵 BATCH CONVERSION STARTED
# ======================================================================
# Input Directory:  C:\Users\Dhanuja\Downloads\dataset\punk_data
# Output Directory: C:\Users\Dhanuja\Downloads\dataset\source
# Files to Process: 28501
# Start Time:       2026-03-02 19:35:04
# ======================================================================
#
# [1/28501] Processing: 00287_My_Mind_A_New_Man,_My_Life_Coach,_He_Shine_instrumental_chunk006_12000ms.mp3
#   └─ Started at 19:35:04
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00287_My_Mind_A_New_Man,_My_Life_Coach,_He_Shine_instrumental_chunk006_12000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00287_My_Mind_A_New_Man,_My_Life_Coach,_He_Shine_instrumental_chunk006_12000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00287_My_Mind_A_New_Man,_My_Life_Coach,_He_Shine_instrumental_chunk006_12000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00287_My_Mind_A_New_Man,_My_Life_Coach,_He_Shine_instrumental_chunk006_12000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00287_My_Mind_A_New_Man,_My_Life_Coach,_He_Shine_instrumental_chunk006_12000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00287_My_Mind_A_New_Man,_My_Life_Coach,_He_Shine_instrumental_chunk006_12000ms_synth.mp3 (154897 bytes)
#   └─ ✓ Success (3.8s, 0.15 MB)
#   └─ Output: 00287_My_Mind_A_New_Man,_My_Life_Coach,_He_Shine_instrumental_chunk006_12000ms_synth.mp3
#
# [2/28501] Processing: 00106_Farmer's_Boulevard_Key_Avenue_instrumental_chunk010_20000ms.mp3
#   └─ Started at 19:35:08
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00106_Farmer's_Boulevard_Key_Avenue_instrumental_chunk010_20000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00106_Farmer's_Boulevard_Key_Avenue_instrumental_chunk010_20000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00106_Farmer's_Boulevard_Key_Avenue_instrumental_chunk010_20000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00106_Farmer's_Boulevard_Key_Avenue_instrumental_chunk010_20000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00106_Farmer's_Boulevard_Key_Avenue_instrumental_chunk010_20000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00106_Farmer's_Boulevard_Key_Avenue_instrumental_chunk010_20000ms_synth.mp3 (160540 bytes)
#   └─ ✓ Success (2.0s, 0.15 MB)
#   └─ Output: 00106_Farmer's_Boulevard_Key_Avenue_instrumental_chunk010_20000ms_synth.mp3
#
# [3/28501] Processing: 01645_Neutral_Fixation_Instigator_instrumental_chunk003_6000ms.mp3
#   └─ Started at 19:35:10
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01645_Neutral_Fixation_Instigator_instrumental_chunk003_6000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01645_Neutral_Fixation_Instigator_instrumental_chunk003_6000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01645_Neutral_Fixation_Instigator_instrumental_chunk003_6000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01645_Neutral_Fixation_Instigator_instrumental_chunk003_6000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01645_Neutral_Fixation_Instigator_instrumental_chunk003_6000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01645_Neutral_Fixation_Instigator_instrumental_chunk003_6000ms_synth.mp3 (157405 bytes)
#   └─ ✓ Success (2.1s, 0.15 MB)
#   └─ Output: 01645_Neutral_Fixation_Instigator_instrumental_chunk003_6000ms_synth.mp3
#
# [4/28501] Processing: 01236_Чокнутый_Пропеллер_Кортни_Лав_instrumental_chunk000_0ms.mp3
#   └─ Started at 19:35:12
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01236_Чокнутый_Пропеллер_Кортни_Лав_instrumental_chunk000_0ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01236_Чокнутый_Пропеллер_Кортни_Лав_instrumental_chunk000_0ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01236_Чокнутый_Пропеллер_Кортни_Лав_instrumental_chunk000_0ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01236_Чокнутый_Пропеллер_Кортни_Лав_instrumental_chunk000_0ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01236_Чокнутый_Пропеллер_Кортни_Лав_instrumental_chunk000_0ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01236_Чокнутый_Пропеллер_Кортни_Лав_instrumental_chunk000_0ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (1.9s, 0.15 MB)
#   └─ Output: 01236_Чокнутый_Пропеллер_Кортни_Лав_instrumental_chunk000_0ms_synth.mp3
#
# [5/28501] Processing: 01763_Fanny_Kaplan_Krasnotelie_Lesa_instrumental_chunk005_10000ms.mp3
#   └─ Started at 19:35:14
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01763_Fanny_Kaplan_Krasnotelie_Lesa_instrumental_chunk005_10000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01763_Fanny_Kaplan_Krasnotelie_Lesa_instrumental_chunk005_10000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01763_Fanny_Kaplan_Krasnotelie_Lesa_instrumental_chunk005_10000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01763_Fanny_Kaplan_Krasnotelie_Lesa_instrumental_chunk005_10000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01763_Fanny_Kaplan_Krasnotelie_Lesa_instrumental_chunk005_10000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01763_Fanny_Kaplan_Krasnotelie_Lesa_instrumental_chunk005_10000ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (1.9s, 0.15 MB)
#   └─ Output: 01763_Fanny_Kaplan_Krasnotelie_Lesa_instrumental_chunk005_10000ms_synth.mp3
#
# [6/28501] Processing: 01315_Botinki_Ra_Lewy_instrumental_chunk004_8000ms.mp3
#   └─ Started at 19:35:16
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01315_Botinki_Ra_Lewy_instrumental_chunk004_8000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01315_Botinki_Ra_Lewy_instrumental_chunk004_8000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01315_Botinki_Ra_Lewy_instrumental_chunk004_8000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01315_Botinki_Ra_Lewy_instrumental_chunk004_8000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01315_Botinki_Ra_Lewy_instrumental_chunk004_8000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01315_Botinki_Ra_Lewy_instrumental_chunk004_8000ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (1.9s, 0.15 MB)
#   └─ Output: 01315_Botinki_Ra_Lewy_instrumental_chunk004_8000ms_synth.mp3
#
# [7/28501] Processing: 00118_Virus_Dogs_Eye_View_instrumental_chunk010_20000ms.mp3
#   └─ Started at 19:35:18
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00118_Virus_Dogs_Eye_View_instrumental_chunk010_20000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00118_Virus_Dogs_Eye_View_instrumental_chunk010_20000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00118_Virus_Dogs_Eye_View_instrumental_chunk010_20000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00118_Virus_Dogs_Eye_View_instrumental_chunk010_20000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00118_Virus_Dogs_Eye_View_instrumental_chunk010_20000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00118_Virus_Dogs_Eye_View_instrumental_chunk010_20000ms_synth.mp3 (136716 bytes)
#   └─ ✓ Success (1.9s, 0.13 MB)
#   └─ Output: 00118_Virus_Dogs_Eye_View_instrumental_chunk010_20000ms_synth.mp3
#
# [8/28501] Processing: 01937_Zerodent_Own_And_Only_Friend_instrumental_chunk000_0ms.mp3
#   └─ Started at 19:35:20
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01937_Zerodent_Own_And_Only_Friend_instrumental_chunk000_0ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01937_Zerodent_Own_And_Only_Friend_instrumental_chunk000_0ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01937_Zerodent_Own_And_Only_Friend_instrumental_chunk000_0ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01937_Zerodent_Own_And_Only_Friend_instrumental_chunk000_0ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01937_Zerodent_Own_And_Only_Friend_instrumental_chunk000_0ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01937_Zerodent_Own_And_Only_Friend_instrumental_chunk000_0ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (2.0s, 0.15 MB)
#   └─ Output: 01937_Zerodent_Own_And_Only_Friend_instrumental_chunk000_0ms_synth.mp3
#
# [9/28501] Processing: 00713_No_Class_Let_Down_instrumental_chunk004_8000ms.mp3
#   └─ Started at 19:35:22
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00713_No_Class_Let_Down_instrumental_chunk004_8000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00713_No_Class_Let_Down_instrumental_chunk004_8000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00713_No_Class_Let_Down_instrumental_chunk004_8000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00713_No_Class_Let_Down_instrumental_chunk004_8000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00713_No_Class_Let_Down_instrumental_chunk004_8000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00713_No_Class_Let_Down_instrumental_chunk004_8000ms_synth.mp3 (159286 bytes)
#   └─ ✓ Success (2.0s, 0.15 MB)
#   └─ Output: 00713_No_Class_Let_Down_instrumental_chunk004_8000ms_synth.mp3
#
# [10/28501] Processing: 00468_The_Cute_Lepers_All_This_Attention_Is_Killing_Me_instrumental_chunk009_18000ms.mp3
#   └─ Started at 19:35:24
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00468_The_Cute_Lepers_All_This_Attention_Is_Killing_Me_instrumental_chunk009_18000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00468_The_Cute_Lepers_All_This_Attention_Is_Killing_Me_instrumental_chunk009_18000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00468_The_Cute_Lepers_All_This_Attention_Is_Killing_Me_instrumental_chunk009_18000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00468_The_Cute_Lepers_All_This_Attention_Is_Killing_Me_instrumental_chunk009_18000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00468_The_Cute_Lepers_All_This_Attention_Is_Killing_Me_instrumental_chunk009_18000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00468_The_Cute_Lepers_All_This_Attention_Is_Killing_Me_instrumental_chunk009_18000ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (2.0s, 0.15 MB)
#   └─ Output: 00468_The_Cute_Lepers_All_This_Attention_Is_Killing_Me_instrumental_chunk009_18000ms_synth.mp3
#
# [11/28501] Processing: 01862_half_cocked_Heart_of_The_City_instrumental_chunk011_22000ms.mp3
#   └─ Started at 19:35:26
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01862_half_cocked_Heart_of_The_City_instrumental_chunk011_22000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01862_half_cocked_Heart_of_The_City_instrumental_chunk011_22000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01862_half_cocked_Heart_of_The_City_instrumental_chunk011_22000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01862_half_cocked_Heart_of_The_City_instrumental_chunk011_22000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01862_half_cocked_Heart_of_The_City_instrumental_chunk011_22000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01862_half_cocked_Heart_of_The_City_instrumental_chunk011_22000ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (2.0s, 0.15 MB)
#   └─ Output: 01862_half_cocked_Heart_of_The_City_instrumental_chunk011_22000ms_synth.mp3
#
# [12/28501] Processing: 00532_Houdini_Roadshow_Burn_Baby_Burn_instrumental_chunk007_14000ms.mp3
#   └─ Started at 19:35:28
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00532_Houdini_Roadshow_Burn_Baby_Burn_instrumental_chunk007_14000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00532_Houdini_Roadshow_Burn_Baby_Burn_instrumental_chunk007_14000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00532_Houdini_Roadshow_Burn_Baby_Burn_instrumental_chunk007_14000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00532_Houdini_Roadshow_Burn_Baby_Burn_instrumental_chunk007_14000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00532_Houdini_Roadshow_Burn_Baby_Burn_instrumental_chunk007_14000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00532_Houdini_Roadshow_Burn_Baby_Burn_instrumental_chunk007_14000ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (2.4s, 0.15 MB)
#   └─ Output: 00532_Houdini_Roadshow_Burn_Baby_Burn_instrumental_chunk007_14000ms_synth.mp3
#
# [13/28501] Processing: 01840_Drag_Sounds_Blessed_Style_instrumental_chunk002_4000ms.mp3
#   └─ Started at 19:35:31
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01840_Drag_Sounds_Blessed_Style_instrumental_chunk002_4000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01840_Drag_Sounds_Blessed_Style_instrumental_chunk002_4000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01840_Drag_Sounds_Blessed_Style_instrumental_chunk002_4000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01840_Drag_Sounds_Blessed_Style_instrumental_chunk002_4000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01840_Drag_Sounds_Blessed_Style_instrumental_chunk002_4000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01840_Drag_Sounds_Blessed_Style_instrumental_chunk002_4000ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (2.6s, 0.15 MB)
#   └─ Output: 01840_Drag_Sounds_Blessed_Style_instrumental_chunk002_4000ms_synth.mp3
#
# [14/28501] Processing: 00359_The_Shrubs_Work_For_Food_instrumental_chunk010_20000ms.mp3
#   └─ Started at 19:35:33
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00359_The_Shrubs_Work_For_Food_instrumental_chunk010_20000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00359_The_Shrubs_Work_For_Food_instrumental_chunk010_20000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00359_The_Shrubs_Work_For_Food_instrumental_chunk010_20000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00359_The_Shrubs_Work_For_Food_instrumental_chunk010_20000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00359_The_Shrubs_Work_For_Food_instrumental_chunk010_20000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00359_The_Shrubs_Work_For_Food_instrumental_chunk010_20000ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (2.1s, 0.15 MB)
#   └─ Output: 00359_The_Shrubs_Work_For_Food_instrumental_chunk010_20000ms_synth.mp3
#
# [15/28501] Processing: 00499_Smooch_Green_Is_The_Theme_(instrumental)_instrumental_chunk009_18000ms.mp3
#   └─ Started at 19:35:35
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00499_Smooch_Green_Is_The_Theme_(instrumental)_instrumental_chunk009_18000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00499_Smooch_Green_Is_The_Theme_(instrumental)_instrumental_chunk009_18000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00499_Smooch_Green_Is_The_Theme_(instrumental)_instrumental_chunk009_18000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00499_Smooch_Green_Is_The_Theme_(instrumental)_instrumental_chunk009_18000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00499_Smooch_Green_Is_The_Theme_(instrumental)_instrumental_chunk009_18000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00499_Smooch_Green_Is_The_Theme_(instrumental)_instrumental_chunk009_18000ms_synth.mp3 (104742 bytes)
#   └─ ✓ Success (1.9s, 0.10 MB)
#   └─ Output: 00499_Smooch_Green_Is_The_Theme_(instrumental)_instrumental_chunk009_18000ms_synth.mp3
#
# [16/28501] Processing: 01221_Nancy_Holiday_instrumental_chunk011_22000ms.mp3
#   └─ Started at 19:35:37
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01221_Nancy_Holiday_instrumental_chunk011_22000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01221_Nancy_Holiday_instrumental_chunk011_22000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01221_Nancy_Holiday_instrumental_chunk011_22000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01221_Nancy_Holiday_instrumental_chunk011_22000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01221_Nancy_Holiday_instrumental_chunk011_22000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01221_Nancy_Holiday_instrumental_chunk011_22000ms_synth.mp3 (139224 bytes)
#   └─ ✓ Success (2.1s, 0.13 MB)
#   └─ Output: 01221_Nancy_Holiday_instrumental_chunk011_22000ms_synth.mp3
#
# [17/28501] Processing: 01461_Love_Story_In_Blood_Red_Jackknife_instrumental_chunk013_26000ms.mp3
#   └─ Started at 19:35:39
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01461_Love_Story_In_Blood_Red_Jackknife_instrumental_chunk013_26000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01461_Love_Story_In_Blood_Red_Jackknife_instrumental_chunk013_26000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01461_Love_Story_In_Blood_Red_Jackknife_instrumental_chunk013_26000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01461_Love_Story_In_Blood_Red_Jackknife_instrumental_chunk013_26000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01461_Love_Story_In_Blood_Red_Jackknife_instrumental_chunk013_26000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01461_Love_Story_In_Blood_Red_Jackknife_instrumental_chunk013_26000ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (2.0s, 0.15 MB)
#   └─ Output: 01461_Love_Story_In_Blood_Red_Jackknife_instrumental_chunk013_26000ms_synth.mp3
#
# [18/28501] Processing: 01660_Spray_Paint_Cussin'_instrumental_chunk004_8000ms.mp3
#   └─ Started at 19:35:41
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01660_Spray_Paint_Cussin'_instrumental_chunk004_8000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01660_Spray_Paint_Cussin'_instrumental_chunk004_8000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01660_Spray_Paint_Cussin'_instrumental_chunk004_8000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01660_Spray_Paint_Cussin'_instrumental_chunk004_8000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01660_Spray_Paint_Cussin'_instrumental_chunk004_8000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01660_Spray_Paint_Cussin'_instrumental_chunk004_8000ms_synth.mp3 (158032 bytes)
#   └─ ✓ Success (2.3s, 0.15 MB)
#   └─ Output: 01660_Spray_Paint_Cussin'_instrumental_chunk004_8000ms_synth.mp3
#
# [19/28501] Processing: 01096_Railkid_Station_Rumble_instrumental_chunk007_14000ms.mp3
#   └─ Started at 19:35:43
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01096_Railkid_Station_Rumble_instrumental_chunk007_14000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01096_Railkid_Station_Rumble_instrumental_chunk007_14000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01096_Railkid_Station_Rumble_instrumental_chunk007_14000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01096_Railkid_Station_Rumble_instrumental_chunk007_14000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01096_Railkid_Station_Rumble_instrumental_chunk007_14000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01096_Railkid_Station_Rumble_instrumental_chunk007_14000ms_synth.mp3 (156778 bytes)
#   └─ ✓ Success (1.9s, 0.15 MB)
#   └─ Output: 01096_Railkid_Station_Rumble_instrumental_chunk007_14000ms_synth.mp3
#
# [20/28501] Processing: 01211_Distemper_Happy_end_instrumental_chunk008_16000ms.mp3
#   └─ Started at 19:35:45
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01211_Distemper_Happy_end_instrumental_chunk008_16000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01211_Distemper_Happy_end_instrumental_chunk008_16000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01211_Distemper_Happy_end_instrumental_chunk008_16000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01211_Distemper_Happy_end_instrumental_chunk008_16000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01211_Distemper_Happy_end_instrumental_chunk008_16000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01211_Distemper_Happy_end_instrumental_chunk008_16000ms_synth.mp3 (153017 bytes)
#   └─ ✓ Success (1.9s, 0.15 MB)
#   └─ Output: 01211_Distemper_Happy_end_instrumental_chunk008_16000ms_synth.mp3
#
# [21/28501] Processing: 00683_Shaved_Women_Static_instrumental_chunk003_6000ms.mp3
#   └─ Started at 19:35:47
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00683_Shaved_Women_Static_instrumental_chunk003_6000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00683_Shaved_Women_Static_instrumental_chunk003_6000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00683_Shaved_Women_Static_instrumental_chunk003_6000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00683_Shaved_Women_Static_instrumental_chunk003_6000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00683_Shaved_Women_Static_instrumental_chunk003_6000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00683_Shaved_Women_Static_instrumental_chunk003_6000ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (2.0s, 0.15 MB)
#   └─ Output: 00683_Shaved_Women_Static_instrumental_chunk003_6000ms_synth.mp3
#
# [22/28501] Processing: 00648_Deniz_Tek_Aloha_Steve_and_Danno_instrumental_chunk010_20000ms.mp3
#   └─ Started at 19:35:49
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00648_Deniz_Tek_Aloha_Steve_and_Danno_instrumental_chunk010_20000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00648_Deniz_Tek_Aloha_Steve_and_Danno_instrumental_chunk010_20000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00648_Deniz_Tek_Aloha_Steve_and_Danno_instrumental_chunk010_20000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00648_Deniz_Tek_Aloha_Steve_and_Danno_instrumental_chunk010_20000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00648_Deniz_Tek_Aloha_Steve_and_Danno_instrumental_chunk010_20000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00648_Deniz_Tek_Aloha_Steve_and_Danno_instrumental_chunk010_20000ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (2.1s, 0.15 MB)
#   └─ Output: 00648_Deniz_Tek_Aloha_Steve_and_Danno_instrumental_chunk010_20000ms_synth.mp3
#
# [23/28501] Processing: 00052_The_Cute_Lepers_Prove_It_instrumental_chunk008_16000ms.mp3
#   └─ Started at 19:35:51
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00052_The_Cute_Lepers_Prove_It_instrumental_chunk008_16000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00052_The_Cute_Lepers_Prove_It_instrumental_chunk008_16000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00052_The_Cute_Lepers_Prove_It_instrumental_chunk008_16000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00052_The_Cute_Lepers_Prove_It_instrumental_chunk008_16000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00052_The_Cute_Lepers_Prove_It_instrumental_chunk008_16000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00052_The_Cute_Lepers_Prove_It_instrumental_chunk008_16000ms_synth.mp3 (158659 bytes)
#   └─ ✓ Success (1.9s, 0.15 MB)
#   └─ Output: 00052_The_Cute_Lepers_Prove_It_instrumental_chunk008_16000ms_synth.mp3
#
# [24/28501] Processing: 00784_Pink_Reason_Ache_For_You_instrumental_chunk007_14000ms.mp3
#   └─ Started at 19:35:53
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00784_Pink_Reason_Ache_For_You_instrumental_chunk007_14000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00784_Pink_Reason_Ache_For_You_instrumental_chunk007_14000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00784_Pink_Reason_Ache_For_You_instrumental_chunk007_14000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00784_Pink_Reason_Ache_For_You_instrumental_chunk007_14000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00784_Pink_Reason_Ache_For_You_instrumental_chunk007_14000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00784_Pink_Reason_Ache_For_You_instrumental_chunk007_14000ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (2.0s, 0.15 MB)
#   └─ Output: 00784_Pink_Reason_Ache_For_You_instrumental_chunk007_14000ms_synth.mp3
#
# [25/28501] Processing: 00830_Foster_Care_Don't_Make_Me_Punch_Yer_Lights_Out_instrumental_chunk006_12000ms.mp3
#   └─ Started at 19:35:55
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00830_Foster_Care_Don't_Make_Me_Punch_Yer_Lights_Out_instrumental_chunk006_12000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00830_Foster_Care_Don't_Make_Me_Punch_Yer_Lights_Out_instrumental_chunk006_12000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00830_Foster_Care_Don't_Make_Me_Punch_Yer_Lights_Out_instrumental_chunk006_12000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00830_Foster_Care_Don't_Make_Me_Punch_Yer_Lights_Out_instrumental_chunk006_12000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00830_Foster_Care_Don't_Make_Me_Punch_Yer_Lights_Out_instrumental_chunk006_12000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00830_Foster_Care_Don't_Make_Me_Punch_Yer_Lights_Out_instrumental_chunk006_12000ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (2.2s, 0.15 MB)
#   └─ Output: 00830_Foster_Care_Don't_Make_Me_Punch_Yer_Lights_Out_instrumental_chunk006_12000ms_synth.mp3
#
# [26/28501] Processing: 01266_La_Misma_Fado_instrumental_chunk007_14000ms.mp3
#   └─ Started at 19:35:57
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01266_La_Misma_Fado_instrumental_chunk007_14000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01266_La_Misma_Fado_instrumental_chunk007_14000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01266_La_Misma_Fado_instrumental_chunk007_14000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01266_La_Misma_Fado_instrumental_chunk007_14000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01266_La_Misma_Fado_instrumental_chunk007_14000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01266_La_Misma_Fado_instrumental_chunk007_14000ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (2.2s, 0.15 MB)
#   └─ Output: 01266_La_Misma_Fado_instrumental_chunk007_14000ms_synth.mp3
#
# [27/28501] Processing: 01919_Hurry_Up_Kick_Em_Out_instrumental_chunk011_22000ms.mp3
#   └─ Started at 19:36:00
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01919_Hurry_Up_Kick_Em_Out_instrumental_chunk011_22000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01919_Hurry_Up_Kick_Em_Out_instrumental_chunk011_22000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01919_Hurry_Up_Kick_Em_Out_instrumental_chunk011_22000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01919_Hurry_Up_Kick_Em_Out_instrumental_chunk011_22000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01919_Hurry_Up_Kick_Em_Out_instrumental_chunk011_22000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01919_Hurry_Up_Kick_Em_Out_instrumental_chunk011_22000ms_synth.mp3 (157405 bytes)
#   └─ ✓ Success (2.1s, 0.15 MB)
#   └─ Output: 01919_Hurry_Up_Kick_Em_Out_instrumental_chunk011_22000ms_synth.mp3
#
# [28/28501] Processing: 00501_Smooch_Pick_Me_Up_(instrumental)_instrumental_chunk000_0ms.mp3
#   └─ Started at 19:36:02
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00501_Smooch_Pick_Me_Up_(instrumental)_instrumental_chunk000_0ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00501_Smooch_Pick_Me_Up_(instrumental)_instrumental_chunk000_0ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00501_Smooch_Pick_Me_Up_(instrumental)_instrumental_chunk000_0ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00501_Smooch_Pick_Me_Up_(instrumental)_instrumental_chunk000_0ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00501_Smooch_Pick_Me_Up_(instrumental)_instrumental_chunk000_0ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00501_Smooch_Pick_Me_Up_(instrumental)_instrumental_chunk000_0ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (2.4s, 0.15 MB)
#   └─ Output: 00501_Smooch_Pick_Me_Up_(instrumental)_instrumental_chunk000_0ms_synth.mp3
#
# [29/28501] Processing: 00667_PUNKASILA_KOPASSUS_instrumental_chunk007_14000ms.mp3
#   └─ Started at 19:36:04
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00667_PUNKASILA_KOPASSUS_instrumental_chunk007_14000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00667_PUNKASILA_KOPASSUS_instrumental_chunk007_14000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00667_PUNKASILA_KOPASSUS_instrumental_chunk007_14000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00667_PUNKASILA_KOPASSUS_instrumental_chunk007_14000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00667_PUNKASILA_KOPASSUS_instrumental_chunk007_14000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00667_PUNKASILA_KOPASSUS_instrumental_chunk007_14000ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (2.8s, 0.15 MB)
#   └─ Output: 00667_PUNKASILA_KOPASSUS_instrumental_chunk007_14000ms_synth.mp3
#
# [30/28501] Processing: 01674_Waylon_Thornton_and_the_Heavy_Hands_Eat_You_Up_instrumental_chunk006_12000ms.mp3
#   └─ Started at 19:36:07
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01674_Waylon_Thornton_and_the_Heavy_Hands_Eat_You_Up_instrumental_chunk006_12000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01674_Waylon_Thornton_and_the_Heavy_Hands_Eat_You_Up_instrumental_chunk006_12000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01674_Waylon_Thornton_and_the_Heavy_Hands_Eat_You_Up_instrumental_chunk006_12000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01674_Waylon_Thornton_and_the_Heavy_Hands_Eat_You_Up_instrumental_chunk006_12000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01674_Waylon_Thornton_and_the_Heavy_Hands_Eat_You_Up_instrumental_chunk006_12000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01674_Waylon_Thornton_and_the_Heavy_Hands_Eat_You_Up_instrumental_chunk006_12000ms_synth.mp3 (144866 bytes)
#   └─ ✓ Success (2.1s, 0.14 MB)
#   └─ Output: 01674_Waylon_Thornton_and_the_Heavy_Hands_Eat_You_Up_instrumental_chunk006_12000ms_synth.mp3
#
# [31/28501] Processing: 00028_SUX_What_I_Did_On_My_Vacation_instrumental_chunk009_18000ms.mp3
#   └─ Started at 19:36:09
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00028_SUX_What_I_Did_On_My_Vacation_instrumental_chunk009_18000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00028_SUX_What_I_Did_On_My_Vacation_instrumental_chunk009_18000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00028_SUX_What_I_Did_On_My_Vacation_instrumental_chunk009_18000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00028_SUX_What_I_Did_On_My_Vacation_instrumental_chunk009_18000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00028_SUX_What_I_Did_On_My_Vacation_instrumental_chunk009_18000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00028_SUX_What_I_Did_On_My_Vacation_instrumental_chunk009_18000ms_synth.mp3 (157405 bytes)
#   └─ ✓ Success (2.4s, 0.15 MB)
#   └─ Output: 00028_SUX_What_I_Did_On_My_Vacation_instrumental_chunk009_18000ms_synth.mp3
#
# [32/28501] Processing: 00522_Ljudske_Potrebe_Udruženje_građana_(live)_instrumental_chunk003_6000ms.mp3
#   └─ Started at 19:36:11
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00522_Ljudske_Potrebe_Udruženje_građana_(live)_instrumental_chunk003_6000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00522_Ljudske_Potrebe_Udruženje_građana_(live)_instrumental_chunk003_6000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00522_Ljudske_Potrebe_Udruženje_građana_(live)_instrumental_chunk003_6000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00522_Ljudske_Potrebe_Udruženje_građana_(live)_instrumental_chunk003_6000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00522_Ljudske_Potrebe_Udruženje_građana_(live)_instrumental_chunk003_6000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00522_Ljudske_Potrebe_Udruženje_građana_(live)_instrumental_chunk003_6000ms_synth.mp3 (49572 bytes)
#   └─ ✓ Success (3.0s, 0.05 MB)
#   └─ Output: 00522_Ljudske_Potrebe_Udruženje_građana_(live)_instrumental_chunk003_6000ms_synth.mp3
#
# [33/28501] Processing: 01148_Violins_is_not_the_answer_SCUMFUCK_instrumental_chunk004_8000ms.mp3
#   └─ Started at 19:36:14
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01148_Violins_is_not_the_answer_SCUMFUCK_instrumental_chunk004_8000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01148_Violins_is_not_the_answer_SCUMFUCK_instrumental_chunk004_8000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01148_Violins_is_not_the_answer_SCUMFUCK_instrumental_chunk004_8000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01148_Violins_is_not_the_answer_SCUMFUCK_instrumental_chunk004_8000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01148_Violins_is_not_the_answer_SCUMFUCK_instrumental_chunk004_8000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01148_Violins_is_not_the_answer_SCUMFUCK_instrumental_chunk004_8000ms_synth.mp3 (159286 bytes)
#   └─ ✓ Success (3.5s, 0.15 MB)
#   └─ Output: 01148_Violins_is_not_the_answer_SCUMFUCK_instrumental_chunk004_8000ms_synth.mp3
#
# [34/28501] Processing: 01378_Even_Twice_Myriad_instrumental_chunk012_24000ms.mp3
#   └─ Started at 19:36:18
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01378_Even_Twice_Myriad_instrumental_chunk012_24000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01378_Even_Twice_Myriad_instrumental_chunk012_24000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01378_Even_Twice_Myriad_instrumental_chunk012_24000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01378_Even_Twice_Myriad_instrumental_chunk012_24000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01378_Even_Twice_Myriad_instrumental_chunk012_24000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01378_Even_Twice_Myriad_instrumental_chunk012_24000ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (2.2s, 0.15 MB)
#   └─ Output: 01378_Even_Twice_Myriad_instrumental_chunk012_24000ms_synth.mp3
#
# [35/28501] Processing: 01564_Bummers_Eve_I_Wanna_Die_instrumental_chunk008_16000ms.mp3
#   └─ Started at 19:36:20
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01564_Bummers_Eve_I_Wanna_Die_instrumental_chunk008_16000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01564_Bummers_Eve_I_Wanna_Die_instrumental_chunk008_16000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01564_Bummers_Eve_I_Wanna_Die_instrumental_chunk008_16000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01564_Bummers_Eve_I_Wanna_Die_instrumental_chunk008_16000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01564_Bummers_Eve_I_Wanna_Die_instrumental_chunk008_16000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01564_Bummers_Eve_I_Wanna_Die_instrumental_chunk008_16000ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (2.2s, 0.15 MB)
#   └─ Output: 01564_Bummers_Eve_I_Wanna_Die_instrumental_chunk008_16000ms_synth.mp3
#
# [36/28501] Processing: 00413_Milk_Music_Interview_instrumental_chunk004_8000ms.mp3
#   └─ Started at 19:36:22
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00413_Milk_Music_Interview_instrumental_chunk004_8000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00413_Milk_Music_Interview_instrumental_chunk004_8000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00413_Milk_Music_Interview_instrumental_chunk004_8000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00413_Milk_Music_Interview_instrumental_chunk004_8000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00413_Milk_Music_Interview_instrumental_chunk004_8000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00413_Milk_Music_Interview_instrumental_chunk004_8000ms_synth.mp3 (158659 bytes)
#   └─ ✓ Success (2.1s, 0.15 MB)
#   └─ Output: 00413_Milk_Music_Interview_instrumental_chunk004_8000ms_synth.mp3
#
# [37/28501] Processing: 00773_Oferta_Especial_Polska_instrumental_chunk009_18000ms.mp3
#   └─ Started at 19:36:25
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00773_Oferta_Especial_Polska_instrumental_chunk009_18000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00773_Oferta_Especial_Polska_instrumental_chunk009_18000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00773_Oferta_Especial_Polska_instrumental_chunk009_18000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00773_Oferta_Especial_Polska_instrumental_chunk009_18000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00773_Oferta_Especial_Polska_instrumental_chunk009_18000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00773_Oferta_Especial_Polska_instrumental_chunk009_18000ms_synth.mp3 (160540 bytes)
#   └─ ✓ Success (2.9s, 0.15 MB)
#   └─ Output: 00773_Oferta_Especial_Polska_instrumental_chunk009_18000ms_synth.mp3
#
# [38/28501] Processing: 00946_Rations_The_Profiteers_instrumental_chunk012_24000ms.mp3
#   └─ Started at 19:36:27
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00946_Rations_The_Profiteers_instrumental_chunk012_24000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00946_Rations_The_Profiteers_instrumental_chunk012_24000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00946_Rations_The_Profiteers_instrumental_chunk012_24000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00946_Rations_The_Profiteers_instrumental_chunk012_24000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00946_Rations_The_Profiteers_instrumental_chunk012_24000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00946_Rations_The_Profiteers_instrumental_chunk012_24000ms_synth.mp3 (158659 bytes)
#   └─ ✓ Success (2.9s, 0.15 MB)
#   └─ Output: 00946_Rations_The_Profiteers_instrumental_chunk012_24000ms_synth.mp3
#
# [39/28501] Processing: 01243_Live_Fast_Die_Guitar_Star_instrumental_chunk003_6000ms.mp3
#   └─ Started at 19:36:30
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01243_Live_Fast_Die_Guitar_Star_instrumental_chunk003_6000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01243_Live_Fast_Die_Guitar_Star_instrumental_chunk003_6000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01243_Live_Fast_Die_Guitar_Star_instrumental_chunk003_6000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01243_Live_Fast_Die_Guitar_Star_instrumental_chunk003_6000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01243_Live_Fast_Die_Guitar_Star_instrumental_chunk003_6000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01243_Live_Fast_Die_Guitar_Star_instrumental_chunk003_6000ms_synth.mp3 (160540 bytes)
#   └─ ✓ Success (2.6s, 0.15 MB)
#   └─ Output: 01243_Live_Fast_Die_Guitar_Star_instrumental_chunk003_6000ms_synth.mp3
#
# [40/28501] Processing: 00788_Black_Bones_We_Will_Rise_Again_instrumental_chunk012_24000ms.mp3
#   └─ Started at 19:36:33
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00788_Black_Bones_We_Will_Rise_Again_instrumental_chunk012_24000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00788_Black_Bones_We_Will_Rise_Again_instrumental_chunk012_24000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00788_Black_Bones_We_Will_Rise_Again_instrumental_chunk012_24000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00788_Black_Bones_We_Will_Rise_Again_instrumental_chunk012_24000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00788_Black_Bones_We_Will_Rise_Again_instrumental_chunk012_24000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00788_Black_Bones_We_Will_Rise_Again_instrumental_chunk012_24000ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (2.1s, 0.15 MB)
#   └─ Output: 00788_Black_Bones_We_Will_Rise_Again_instrumental_chunk012_24000ms_synth.mp3
#
# [41/28501] Processing: 00062_Boss_Hog_Trouble_instrumental_chunk011_22000ms.mp3
#   └─ Started at 19:36:35
# ...
#   └─ ✓ Success (2.6s, 0.15 MB)
#   └─ Output: 01801_Keith_Doom_and_the_Wrecking_Crew_Dead_Byrds_instrumental_chunk008_16000ms_synth.mp3
#
# [241/28501] Processing: 01988_Sonic_Avenues_Death_Trap_instrumental_chunk004_8000ms.mp3
#   └─ Started at 19:43:37
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01988_Sonic_Avenues_Death_Trap_instrumental_chunk004_8000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01988_Sonic_Avenues_Death_Trap_instrumental_chunk004_8000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01988_Sonic_Avenues_Death_Trap_instrumental_chunk004_8000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01988_Sonic_Avenues_Death_Trap_instrumental_chunk004_8000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01988_Sonic_Avenues_Death_Trap_instrumental_chunk004_8000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01988_Sonic_Avenues_Death_Trap_instrumental_chunk004_8000ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (2.6s, 0.15 MB)
#   └─ Output: 01988_Sonic_Avenues_Death_Trap_instrumental_chunk004_8000ms_synth.mp3
#
# [242/28501] Processing: 01220_Nancy_Long_Island_Lovin'_instrumental_chunk013_26000ms.mp3
#   └─ Started at 19:43:39
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01220_Nancy_Long_Island_Lovin'_instrumental_chunk013_26000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01220_Nancy_Long_Island_Lovin'_instrumental_chunk013_26000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01220_Nancy_Long_Island_Lovin'_instrumental_chunk013_26000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01220_Nancy_Long_Island_Lovin'_instrumental_chunk013_26000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01220_Nancy_Long_Island_Lovin'_instrumental_chunk013_26000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01220_Nancy_Long_Island_Lovin'_instrumental_chunk013_26000ms_synth.mp3 (155524 bytes)
#   └─ ✓ Success (2.4s, 0.15 MB)
#   └─ Output: 01220_Nancy_Long_Island_Lovin'_instrumental_chunk013_26000ms_synth.mp3
#
# [243/28501] Processing: 00219_Mob_Action_yer_lucky_instrumental_chunk013_26000ms.mp3
#   └─ Started at 19:43:42
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00219_Mob_Action_yer_lucky_instrumental_chunk013_26000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00219_Mob_Action_yer_lucky_instrumental_chunk013_26000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00219_Mob_Action_yer_lucky_instrumental_chunk013_26000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00219_Mob_Action_yer_lucky_instrumental_chunk013_26000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00219_Mob_Action_yer_lucky_instrumental_chunk013_26000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00219_Mob_Action_yer_lucky_instrumental_chunk013_26000ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (2.7s, 0.15 MB)
#   └─ Output: 00219_Mob_Action_yer_lucky_instrumental_chunk013_26000ms_synth.mp3
#
# [244/28501] Processing: 01028_Los_Margaritos_Mordida_De_Leon_instrumental_chunk012_24000ms.mp3
#   └─ Started at 19:43:44
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01028_Los_Margaritos_Mordida_De_Leon_instrumental_chunk012_24000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01028_Los_Margaritos_Mordida_De_Leon_instrumental_chunk012_24000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01028_Los_Margaritos_Mordida_De_Leon_instrumental_chunk012_24000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01028_Los_Margaritos_Mordida_De_Leon_instrumental_chunk012_24000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01028_Los_Margaritos_Mordida_De_Leon_instrumental_chunk012_24000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01028_Los_Margaritos_Mordida_De_Leon_instrumental_chunk012_24000ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (3.0s, 0.15 MB)
#   └─ Output: 01028_Los_Margaritos_Mordida_De_Leon_instrumental_chunk012_24000ms_synth.mp3
#
# [245/28501] Processing: 01700_Reanimadores_40_instrumental_chunk012_24000ms.mp3
#   └─ Started at 19:43:47
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01700_Reanimadores_40_instrumental_chunk012_24000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01700_Reanimadores_40_instrumental_chunk012_24000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01700_Reanimadores_40_instrumental_chunk012_24000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01700_Reanimadores_40_instrumental_chunk012_24000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01700_Reanimadores_40_instrumental_chunk012_24000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01700_Reanimadores_40_instrumental_chunk012_24000ms_synth.mp3 (157405 bytes)
#   └─ ✓ Success (2.7s, 0.15 MB)
#   └─ Output: 01700_Reanimadores_40_instrumental_chunk012_24000ms_synth.mp3
#
# [246/28501] Processing: 00462_Ivan_Julian_Young_Man's_Money_instrumental_chunk005_10000ms.mp3
#   └─ Started at 19:43:50
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00462_Ivan_Julian_Young_Man's_Money_instrumental_chunk005_10000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00462_Ivan_Julian_Young_Man's_Money_instrumental_chunk005_10000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00462_Ivan_Julian_Young_Man's_Money_instrumental_chunk005_10000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00462_Ivan_Julian_Young_Man's_Money_instrumental_chunk005_10000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00462_Ivan_Julian_Young_Man's_Money_instrumental_chunk005_10000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00462_Ivan_Julian_Young_Man's_Money_instrumental_chunk005_10000ms_synth.mp3 (159286 bytes)
#   └─ ✓ Success (2.6s, 0.15 MB)
#   └─ Output: 00462_Ivan_Julian_Young_Man's_Money_instrumental_chunk005_10000ms_synth.mp3
#
# [247/28501] Processing: 00369_Waylon_Thornton_and_the_Heavy_Hands_Bored_and_Alone_instrumental_chunk001_2000ms.mp3
#   └─ Started at 19:43:53
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00369_Waylon_Thornton_and_the_Heavy_Hands_Bored_and_Alone_instrumental_chunk001_2000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00369_Waylon_Thornton_and_the_Heavy_Hands_Bored_and_Alone_instrumental_chunk001_2000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00369_Waylon_Thornton_and_the_Heavy_Hands_Bored_and_Alone_instrumental_chunk001_2000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00369_Waylon_Thornton_and_the_Heavy_Hands_Bored_and_Alone_instrumental_chunk001_2000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00369_Waylon_Thornton_and_the_Heavy_Hands_Bored_and_Alone_instrumental_chunk001_2000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00369_Waylon_Thornton_and_the_Heavy_Hands_Bored_and_Alone_instrumental_chunk001_2000ms_synth.mp3 (149255 bytes)
#   └─ ✓ Success (2.1s, 0.14 MB)
#   └─ Output: 00369_Waylon_Thornton_and_the_Heavy_Hands_Bored_and_Alone_instrumental_chunk001_2000ms_synth.mp3
#
# [248/28501] Processing: 00827_Foster_Care_Justify_To_Me_instrumental_chunk006_12000ms.mp3
#   └─ Started at 19:43:55
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00827_Foster_Care_Justify_To_Me_instrumental_chunk006_12000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00827_Foster_Care_Justify_To_Me_instrumental_chunk006_12000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00827_Foster_Care_Justify_To_Me_instrumental_chunk006_12000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00827_Foster_Care_Justify_To_Me_instrumental_chunk006_12000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00827_Foster_Care_Justify_To_Me_instrumental_chunk006_12000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00827_Foster_Care_Justify_To_Me_instrumental_chunk006_12000ms_synth.mp3 (154271 bytes)
#   └─ ✓ Success (2.0s, 0.15 MB)
#   └─ Output: 00827_Foster_Care_Justify_To_Me_instrumental_chunk006_12000ms_synth.mp3
#
# [249/28501] Processing: 01962_The_Zombie_Dandies_Addicted_instrumental_chunk006_12000ms.mp3
#   └─ Started at 19:43:57
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01962_The_Zombie_Dandies_Addicted_instrumental_chunk006_12000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01962_The_Zombie_Dandies_Addicted_instrumental_chunk006_12000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01962_The_Zombie_Dandies_Addicted_instrumental_chunk006_12000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01962_The_Zombie_Dandies_Addicted_instrumental_chunk006_12000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01962_The_Zombie_Dandies_Addicted_instrumental_chunk006_12000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01962_The_Zombie_Dandies_Addicted_instrumental_chunk006_12000ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (2.1s, 0.15 MB)
#   └─ Output: 01962_The_Zombie_Dandies_Addicted_instrumental_chunk006_12000ms_synth.mp3
#
# [250/28501] Processing: 01524_Gegorly_Merits_and_Demerits_of_the_Trojan_Horse_instrumental_chunk011_22000ms.mp3
#   └─ Started at 19:43:59
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01524_Gegorly_Merits_and_Demerits_of_the_Trojan_Horse_instrumental_chunk011_22000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01524_Gegorly_Merits_and_Demerits_of_the_Trojan_Horse_instrumental_chunk011_22000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01524_Gegorly_Merits_and_Demerits_of_the_Trojan_Horse_instrumental_chunk011_22000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01524_Gegorly_Merits_and_Demerits_of_the_Trojan_Horse_instrumental_chunk011_22000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01524_Gegorly_Merits_and_Demerits_of_the_Trojan_Horse_instrumental_chunk011_22000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\01524_Gegorly_Merits_and_Demerits_of_the_Trojan_Horse_instrumental_chunk011_22000ms_synth.mp3 (155524 bytes)
#   └─ ✓ Success (2.0s, 0.15 MB)
#   └─ Output: 01524_Gegorly_Merits_and_Demerits_of_the_Trojan_Horse_instrumental_chunk011_22000ms_synth.mp3
#
# [251/28501] Processing: 00354_Occult_Detective_Club_Crimes_instrumental_chunk007_14000ms.mp3
#   └─ Started at 19:44:01
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00354_Occult_Detective_Club_Crimes_instrumental_chunk007_14000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\00354_Occult_Detective_Club_Crimes_instrumental_chunk007_14000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\00354_Occult_Detective_Club_Crimes_instrumental_chunk007_14000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\00354_Occult_Detective_Club_Crimes_instrumental_chunk007_14000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\00354_Occult_Detective_Club_Crimes_instrumental_chunk007_14000ms_synth.mp3
# Converting WAV to MP3...
# MP3 file created: C:\Users\Dhanuja\Downloads\dataset\source\00354_Occult_Detective_Club_Crimes_instrumental_chunk007_14000ms_synth.mp3 (159913 bytes)
#   └─ ✓ Success (2.1s, 0.15 MB)
#   └─ Output: 00354_Occult_Detective_Club_Crimes_instrumental_chunk007_14000ms_synth.mp3
#
# [252/28501] Processing: 01598_Octagrape_Sungazers_instrumental_chunk004_8000ms.mp3
#   └─ Started at 19:44:03
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01598_Octagrape_Sungazers_instrumental_chunk004_8000ms.mp3...
# Predicting MIDI for C:\Users\Dhanuja\Downloads\dataset\punk_data\01598_Octagrape_Sungazers_instrumental_chunk004_8000ms.mp3...
# MIDI file created: C:\Users\Dhanuja\Downloads\dataset\source\01598_Octagrape_Sungazers_instrumental_chunk004_8000ms_basic_pitch.mid
# Converting MIDI to audio...
#   FluidSynth: C:\Users\Dhanuja\scoop\apps\fluidsynth\current\bin\fluidsynth.EXE
#   Input MIDI: C:\Users\Dhanuja\Downloads\dataset\source\01598_Octagrape_Sungazers_instrumental_chunk004_8000ms_basic_pitch.mid
#   Output: C:\Users\Dhanuja\Downloads\dataset\source\01598_Octagrape_Sungazers_instrumental_chunk004_8000ms_synth.mp3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       3 OUTPUT_DIR = r"C:\Users\Dhanuja\Downloads\dataset\source"       # Change this to your desired output directory
#       5 # Run batch conversion
# ----> 6 conversion_results = batch_convert_audio_files(INPUT_DIR, OUTPUT_DIR)
#
# Cell In[3], line 59, in batch_convert_audio_files(input_dir, output_dir, audio_formats)
#      55 print(f"  └─ Started at {datetime.now().strftime('%H:%M:%S')}")
#      57 try:
#      58     # Convert audio to MIDI to audio
# ---> 59     output_audio = converter.convert(str(audio_file), output_dir)
#      60     results[str(audio_file)] = output_audio
#      62     file_duration = time.time() - file_start
#
# File ~\Desktop\Vibeshift\VibeShift\utills\audio_midi_converter.py:163, in AudioMidiConverter.convert(self, audio_path, output_dir)
#     160 input_path = Path(audio_path)
#     161 output_audio = os.path.join(output_dir, f"{input_path.stem}_synth.mp3")
# --> 163 audio_path = self.midi_to_audio(midi_path, output_audio)
#     164 return audio_path
#
# File ~\Desktop\Vibeshift\VibeShift\utills\audio_midi_converter.py:128, in AudioMidiConverter.midi_to_audio(self, midi_path, output_path)
#     125 if result.returncode != 0:
#     126     raise RuntimeError(f"FluidSynth failed with return code {result.returncode}:\n{result.stderr}")
# --> 128 time.sleep(1)
#     130 if not os.path.exists(temp_wav):
#     131     raise RuntimeError(f"FluidSynth did not create output file: {temp_wav}")
#
# KeyboardInterrupt:

# %% [markdown]
# ## 5. Visualize and Compare Audio Files
#
# Load and display waveforms, spectrograms, and play audio samples from the converted files.

# %%
# Get successfully converted files
successful_files = [(k, v) for k, v in conversion_results.items() if v is not None]

if not successful_files:
    print("✗ No files were successfully converted")
else:
    print(f"\n✓ {len(successful_files)} file(s) ready for visualization\n")

# %%
def plot_audio_comparison(original_path: str, synth_path: str, title: str = None):
    """
    Plot waveform and spectrogram comparison between original and resynthesized audio.
    
    Args:
        original_path: Path to original audio file
        synth_path: Path to resynthesized audio file
        title: Title for the plot
    """
    if title is None:
        title = Path(original_path).stem
    
    # Load audio files
    y_orig, sr_orig = librosa.load(original_path, sr=None)
    y_synth, sr_synth = librosa.load(synth_path, sr=None)
    
    # Normalize to same length (use shorter length)
    min_len = min(len(y_orig), len(y_synth))
    y_orig = y_orig[:min_len]
    y_synth = y_synth[:min_len]
    
    # Create time axis
    time_axis = np.arange(len(y_orig)) / sr_orig
    
    # Create figure with 4 subplots
    fig, axes = plt.subplots(2, 2, figsize=(16, 10))
    fig.suptitle(f'Audio Comparison: {title}', fontsize=16, fontweight='bold')
    
    # Plot 1: Original Waveform
    axes[0, 0].plot(time_axis, y_orig, linewidth=0.5, color='#0066cc')
    axes[0, 0].set_title('Original Audio - Waveform', fontsize=12, fontweight='bold')
    axes[0, 0].set_xlabel('Time (s)')
    axes[0, 0].set_ylabel('Amplitude')
    axes[0, 0].grid(True, alpha=0.3)
    
    # Plot 2: Resynthesized Waveform
    axes[0, 1].plot(time_axis, y_synth, linewidth=0.5, color='#ff6600')
    axes[0, 1].set_title('Resynthesized Audio - Waveform', fontsize=12, fontweight='bold')
    axes[0, 1].set_xlabel('Time (s)')
    axes[0, 1].set_ylabel('Amplitude')
    axes[0, 1].grid(True, alpha=0.3)
    
    # Plot 3: Original Spectrogram
    S_orig = librosa.stft(y_orig)
    S_db_orig = librosa.power_to_db(np.abs(S_orig) ** 2, ref=np.max)
    img1 = axes[1, 0].imshow(S_db_orig, aspect='auto', origin='lower', cmap='viridis')
    axes[1, 0].set_title('Original Audio - Spectrogram', fontsize=12, fontweight='bold')
    axes[1, 0].set_xlabel('Time')
    axes[1, 0].set_ylabel('Frequency')
    plt.colorbar(img1, ax=axes[1, 0], label='dB')
    
    # Plot 4: Resynthesized Spectrogram
    S_synth = librosa.stft(y_synth)
    S_db_synth = librosa.power_to_db(np.abs(S_synth) ** 2, ref=np.max)
    img2 = axes[1, 1].imshow(S_db_synth, aspect='auto', origin='lower', cmap='viridis')
    axes[1, 1].set_title('Resynthesized Audio - Spectrogram', fontsize=12, fontweight='bold')
    axes[1, 1].set_xlabel('Time')
    axes[1, 1].set_ylabel('Frequency')
    plt.colorbar(img2, ax=axes[1, 1], label='dB')
    
    plt.tight_layout()
    plt.show()
    
    # Print audio statistics
    print(f"\n📊 Audio Statistics for '{title}':")
    print(f"{'='*60}")
    print(f"Original Audio:")
    print(f"  Duration: {len(y_orig)/sr_orig:.2f}s")
    print(f"  Sample Rate: {sr_orig} Hz")
    print(f"  RMS Energy: {np.sqrt(np.mean(y_orig**2)):.4f}")
    print(f"  Peak Amplitude: {np.max(np.abs(y_orig)):.4f}")
    print(f"")
    print(f"Resynthesized Audio:")
    print(f"  Duration: {len(y_synth)/sr_synth:.2f}s")
    print(f"  Sample Rate: {sr_synth} Hz")
    print(f"  RMS Energy: {np.sqrt(np.mean(y_synth**2)):.4f}")
    print(f"  Peak Amplitude: {np.max(np.abs(y_synth)):.4f}")
    print(f"{'='*60}\n")
    
    return y_orig, sr_orig, y_synth, sr_synth

print("✓ Audio comparison function defined")

# %%
# Visualize the first successfully converted file
if successful_files:
    original_path, synth_path = successful_files[0]
    print(f"Visualizing: {Path(original_path).name}")
    print(f"Original: {original_path}")
    print(f"Synthesized: {synth_path}\n")
    
    y_orig, sr_orig, y_synth, sr_synth = plot_audio_comparison(original_path, synth_path)
else:
    print("No files to visualize")

# %% [markdown]
# ## 6. Audio Playback
#
# Listen to the original and resynthesized audio samples.

# %%
if successful_files:
    original_path, synth_path = successful_files[0]
    
    print(f"🎵 Audio Playback: {Path(original_path).stem}\n")
    
    print("Original Audio:")
    display(Audio(original_path, rate=44100))
    
    print("\nResynthesized Audio:")
    display(Audio(synth_path, rate=44100))
    
    print(f"\nOriginal file: {original_path}")
    print(f"Resynthesized file: {synth_path}")
else:
    print("No audio files available for playback")

# %% [markdown]
# ## 7. Visualize All Converted Files (Optional)
#
# Visualize all successfully converted files in a grid.

# %%
if len(successful_files) > 1:
    # Visualize first 4 files (or fewer if less than 4)
    files_to_visualize = successful_files[:4]
    
    print(f"\n{'='*70}")
    print(f"📊 VISUALIZING {len(files_to_visualize)} FILES")
    print(f"{'='*70}\n")
    
    for idx, (original_path, synth_path) in enumerate(files_to_visualize, 1):
        file_name = Path(original_path).stem
        print(f"[{idx}/{len(files_to_visualize)}] {file_name}")
        plot_audio_comparison(original_path, synth_path, title=file_name)
        print()
else:
    print("Only 1 file converted - see visualization above")

# %% [markdown]
# ## Summary
#
# This notebook successfully:
# 1. ✅ Initialized the AudioMidiConverter with FluidSynth support
# 2. ✅ Defined a batch processing function with detailed progress tracking
# 3. ✅ Converted multiple audio files from audio → MIDI → audio format
# 4. ✅ Visualized waveforms and spectrograms of original vs. resynthesized audio
# 5. ✅ Provided audio playback widgets for perceptual evaluation
#
# The output files are saved with `_synth` suffix in the output directory and maintain the original audio format.

# %%
# New markdown cell after section 6
## 6.1. Audio File Details



# New code cell
if successful_files:
    original_path, synth_path = successful_files[200]
    
    # Get file information
    orig_info = sf.info(original_path)
    synth_info = sf.info(synth_path)
    
    # Get file sizes
    orig_size = os.path.getsize(original_path) / (1024 * 1024)  # MB
    synth_size = os.path.getsize(synth_path) / (1024 * 1024)  # MB
    
    print(f"\n{'='*70}")
    print(f"📁 FILE DETAILS: {Path(original_path).stem}")
    print(f"{'='*70}\n")
    
    # Original Audio Details
    print("🎵 ORIGINAL AUDIO:")
    print(f"  File Path:      {original_path}")
    print(f"  File Size:      {orig_size:.2f} MB")
    print(f"  Duration:       {orig_info.duration:.2f} seconds ({orig_info.duration/60:.2f} minutes)")
    print(f"  Sample Rate:    {orig_info.samplerate} Hz")
    print(f"  Total Samples:  {orig_info.frames:,}")
    print(f"  Channels:       {orig_info.channels} ({'Mono' if orig_info.channels == 1 else 'Stereo'})")
    print(f"  Format:         {orig_info.format} / {orig_info.subtype}")
    
    print()
    
    # Resynthesized Audio Details
    print("🎹 RESYNTHESIZED AUDIO:")
    print(f"  File Path:      {synth_path}")
    print(f"  File Size:      {synth_size:.2f} MB")
    print(f"  Duration:       {synth_info.duration:.2f} seconds ({synth_info.duration/60:.2f} minutes)")
    print(f"  Sample Rate:    {synth_info.samplerate} Hz")
    print(f"  Total Samples:  {synth_info.frames:,}")
    print(f"  Channels:       {synth_info.channels} ({'Mono' if synth_info.channels == 1 else 'Stereo'})")
    print(f"  Format:         {synth_info.format} / {synth_info.subtype}")
    
    print()
    
    # Comparison
    print("📊 COMPARISON:")
    print(f"  Size Difference:     {synth_size - orig_size:+.2f} MB ({((synth_size/orig_size - 1) * 100):+.1f}%)")
    print(f"  Duration Difference: {synth_info.duration - orig_info.duration:+.2f} seconds")
    print(f"  Sample Rate Match:   {'✓ Yes' if orig_info.samplerate == synth_info.samplerate else '✗ No'}")
    print(f"  Channel Match:       {'✓ Yes' if orig_info.channels == synth_info.channels else '✗ No'}")
    
    print(f"{'='*70}\n")
else:
    print("No files available for details")
